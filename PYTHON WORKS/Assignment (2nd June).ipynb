# %% [markdown]
# #### Scenario 1: Clean Customer Name
# - name = "   PRIYANKA REDDY   " :
# - output : Priyanka Reddy

# %%
name = " PRIYANKA REDDY "
name.title()
# Out:
# ' Priyanka Reddy '

# %% [markdown]
# #### Scenario 2: Standardize Email
# - email = "   JOHN.SMITH@GMAIL.COM   "
# - Output :john.smith@gmail.com

# %%
email = " JOHN.SMITH@GMAIL.COM "
email.lower()
# Out:
# ' john.smith@gmail.com '

# %% [markdown]
# #### Scenario 3: Replace Product Category
# - product = "Mobile-Phone"
# -- Output : mobile phone

# %%
product = "Mobile-Phone" 
a=product.lower()
a.replace("-"," ")
# Out:
# 'mobile phone'

# %% [markdown]
# #### Scenario 4: Count a Word: PYTHON
# text = "python sql python powerbi python"

# %%
text = "python sql python powerbi python"
text.count("python")
# Out:
# 3

# %% [markdown]
# #### Scenario 5: Extract Skills
# - skills = "Python,SQL,Power BI,Excel"
# - Output : ['Python', 'SQL', 'Power BI', 'Excel']

# %%
skills = "Python,SQL,Power BI,Excel"
skills.split(",")
# Out:
# ['Python', 'SQL', 'Power BI', 'Excel']

# %% [markdown]
# #### Scenario 6: Create CSV String
# - skills = ["Python", "SQL", "Power BI"]
# - Output : Python,SQL,Power BI

# %%
skills = ["Python", "SQL", "Power BI"]
skills_str=",".join(skills)
print(skills_str)
# Out:
# Python,SQL,Power BI

# %% [markdown]
# #### Scenario 7: Check Company Email endnig with .com or not
# - email = "john@apple.com"

# %%
email = "john@apple.com"
email.endswith(".com")
# Out:
# True

# %% [markdown]
# #### Scenario 8: Check Employee Code starts with emp r not
# - emp_code = "EMP123"

# %%
emp_code = "EMP123"
emp_code.startswith("EMP")
# Out:
# True

# %% [markdown]
# #### Scenario 9: Remove Extra Spaces and Convert TO LOWER
# - city = "   HYDERABAD   "

# %%
city = " HYDERABAD "
a=city.strip()
print(a.lower())
# Out:
# hyderabad

# %% [markdown]
# #### Scenario 10: Replace Multiple Words
# - text = "I like Excel and Excel"
# - Output : I like Python and Python

# %%
text = "I like Excel and Excel"
text.replace("Excel","Python")
# Out:
# 'I like Python and Python'

# %% [markdown]
# #### Scenario 11: Find Position of sql
# - text = "Python SQL Power BI"

# %%
text = "Python SQL Power BI"
text.find("SQL")
# Out:
# 7

# %% [markdown]
# #### Scenario 12: Validate Mobile Number is number or not
# - mobile = "9876543210pri"

# %%
mobile = "9876543210pri"
mobile.isdigit()
# Out:
# False

# %% [markdown]
# #### Scenario 13: Validate Customer Name string or not
# - name = "Priyanka"

# %%
name = "Priyanka"
name.isalpha()
# Out:
# True

# %% [markdown]
# #### Scenario 14: Data Cleaning
# - data = "   DATA ANALYTICS   "
# - Output : data science

# %%
data = " DATA ANALYTICS "
a=data.lower()
print(a.replace("analytics","science"))
# Out:
#  data science

# %% [markdown]
# #### Scenario 15: Multiple Method Chaining
# - text = "   PYTHON,SQL,POWER BI   "
# - Output
# python | sql | power bi

# %%
text = " PYTHON,SQL,POWER BI "
a=text.lower()
print(a.replace(",","|"))
# Out:
#  python|sql|power bi
